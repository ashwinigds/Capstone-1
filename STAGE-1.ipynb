# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwinigds/Capstone-1/blob/main/STAGE-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
api_key = "AIzaSyD1uI1Y6LpnCRk9neXkRtTdrF_bjjbMAU0"

# %%
import googleapiclient.discovery

# %%
from pprint import pprint

# %%
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=api_key)

# %%
channel_ID = "UCZjRcM1ukeciMZ7_fvzsezQ"

# %%
def channelDetails(x):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=x
    )
    response = request.execute()


    # Check if 'statistics' key exists in the response
    if 'items' in response :
        # Access statistics data if available
        channel_details = dict(
            channel_name =  response['items'][0]['snippet']['title'],
            channel_id = response['items'][0]['id'],
            channel_description = response['items'][0]['snippet']['description'],
            subscribers_count = response['items'][0]['statistics']['subscriberCount'],
            video_Count = response['items'][0]['statistics']['videoCount'],
            view_Count = response['items'][0]['statistics']['viewCount'],
            published_on = response['items'][0]['snippet']['publishedAt'],
            channel_description = response['items'][0]['snippet']['description'],
            country = response['items'][0]['snippet']
        )
    else:
        # If statistics data is missing, set default values or handle the case accordingly
        channel_details = dict(
            channel_name = response['items'][0]['snippet']['title'],
            channel_id = response['items'][0]['id'],
            subscribers_count = 'N/A',
            video_count = 'N/A',
            view_count = 'N/A',
            published_on = response['items'][0]['snippet']['publishedAt'],
            description = response['items'][0]['snippet']['description'],
            country = response['items'][0]['snippet'].get('country', 'N/A')
        )
    return channel_details


channelDetails('UCZjRcM1ukeciMZ7_fvzsezQ')

# %%
def video_details(y):
  request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        maxResults=25,
        playlistId=y
    )
  react = request.execute()

  video_details = dict(playlist_id = react['items'][0]['snippet']['playlistId'],
                     playlist_title = react['items'][0]['snippet']['title'],
                     description = react['items'][0]['snippet']['description'],
                     published_At = react['items'][0]['snippet']['publishedAt'],

                     )
  return video_details

video_details('UUZjRcM1ukeciMZ7_fvzsezQ')

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id="Ks-_Mh1QhMc"
    )
playlist = request.execute()
video_statistics = dict(video_description = playlist['items'][0]['snippet']['description'],
                        tags = playlist['items'][0]['snippet']['tags'],
                        thumbnails = playlist['items'][0]['snippet']['thumbnails']['default'],
                        comment_count = playlist['items'][0]['statistics']['commentCount'],
                        like_count = playlist['items'][0]['statistics']['likeCount'],
                        view_count = playlist['items'][0]['statistics']['viewCount'],
                        caption_status = playlist['items'][0]['contentDetails']['caption'],
                        duration = playlist['items'][0]['contentDetails']['duration'])
return video_statistics

# %%
video_statistics = dict(video_description = playlist['items'][0]['snippet']['description'],
                        tags = playlist['items'][0]['snippet']['tags'],
                        thumbnails = playlist['items'][0]['snippet']['thumbnails']['default'],
                        comment_count = playlist['items'][0]['statistics']['commentCount'],
                        like_count = playlist['items'][0]['statistics']['likeCount'],
                        view_count = playlist['items'][0]['statistics']['viewCount'],
                        caption_status = playlist['items'][0]['contentDetails']['caption'],
                        duration = playlist['items'][0]['contentDetails']['duration'])
video_statistics

# %%
request = youtube.comments().list(
        part="snippet",
        parentId="UgzDE2tasfmrYLyNkGt4AaABAg"
    )
comments = request.execute()

pprint(comments)
# Out:
# {'etag': 'B5Ab-_DI-jn6znSKHG72VxnPZYc',
#  'items': [{'etag': '5EMxxh3jgdu4oE6pI51uRP9JU08',
#             'id': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjX

#             'id': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjXg9PkcjGo1uKM',
#             'kind': 'youtube#comment',
#             'snippet': {'authorChannelId': {'value': 'UC1ksRS5AgC6ypgpNgBT7wiQ'},
#                         'authorChannelUrl': 'http://www.youtube.com/@StoriesWithGR',
#                         'authorDisplayName': '@StoriesWithGR',
#                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n93ZC2FQ9RoxyEdQMDF2ZZSiYn4bhU96p0orzSw6E=s48-c-k-c0x00ffffff-no-rj',
#                         'canRate': True,
#                         'channelId': 'UCP4bf6IHJJQehibu6ai__cg',
#                         'likeCount': 0,
#                         'parentId': 'UgzDE2tasfmrYLyNkGt4AaABAg',
#                         'publishedAt': '2021-07-13T21:54:13Z',
#                         'textDisplay': 'Why is everyone writing &quot;this is '
#                                        'the original comment &quot;?? 😅',
#                         'textOriginal': 'Why is everyone writing "this is the '
#                                         'original comment "?? 😅',
#                         'updatedAt': '2021-07-13T21:54:13Z',
#                         'viewerRating': 'none'}},
#            {'etag': 'aczOVEUBLIZnrCLNRHOqr4vbO1E',
#             'id': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjXg9Pkvd1UQ-jz',
#             'kind': 'youtube#comment',
#             'snippet': {'authorChannelId': {'value': 'UCuqcdALRoPeWvRnl7u-mnaQ'},
#                         'authorChannelUrl': 'http://www.youtube.com/@questlabsAI',
#                         'authorDisplayName': '@questlabsAI',
#                         'authorProfileImageUrl': 'https://yt3.ggpht.com/84ZNdTY7S0NnQ6m-yj05VTGquI3_JIdRkyHx7npa3L-dTh6ScF79ZfPnNdRBg8sevtzVkdpE5w=s48-c-k-c0x00ffffff-no-rj',
#                         'canRate': True,
#                         'channelId': 'UCP4bf6IHJJQehibu6ai__cg',
#                         'likeCount': 0,
#                         'parentId': 'UgzDE2tasfmrYLyNkGt4AaABAg',
#                         'publishedAt': '2021-07-14T00:39:23Z',
#                         'textDisplay': 'This is the original comment.',
#                         'textOriginal': 'This is the original comment.',
#                         'updatedAt': '2021-07-14T00:39:23Z',
#                         'viewerRating': 'none'}},
#            {'etag': 'Qh-yX_gTyZHgIfvivsdNTjYZ9EE',
#             'id': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjXg9RIvP-S8otK',
#             'kind': 'youtube#comment',
#             'snippet': {'authorChannelId': {'value': 'UCrFzzsyRA0kKQCkwj3q8xaw'},
#                         'authorChannelUrl': 'http://www.youtube.com/@konstantinpanchenko2179',
#                         'authorDisplayName': '@konstantinpanchenko2179',
#                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_luZGdIwGfjK96I0hwc3DWzlMlnF4pNM2yqcw=s48-c-k-c0x00ffffff-no-rj',
#                         'canRate': True,
#                         'channelId': 'UCP4bf6IHJJQehibu6ai__cg',
#                         'likeCount': 0,
#                         'parentId': 'UgzDE2tasfmrYLyNkGt4AaABAg',
#                         'publishedAt': '2021-08-21T11:22:09Z',
#                         'textDisplay': 'Test',
#                         'textOriginal': 'Test',
#                         'updatedAt': '2021-08-21T11:22:09Z',
#                         'viewerRating': 'none'}},
#            {'etag': 'JeQmdyrd1y7m4mDGU9HQq1P0NEw',
#             'id': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjXg9RT71EGKJVm',
#             'kind': 'youtube#comment',
#             'snippet': {'authorChannelId': {'value': 'UCxiu9DiB5Zdx3WodU2ZYV3Q'},
#                         'authorChannelUrl': 'http://www.youtube.com/@mgGelloiss',
#                         'authorDisplayName': '@mgGelloiss',
#                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nlOduXKj_CFVhFqKUlP_qnqwvZiNv2tJdBFu5S=s48-c-k-c0x00ffffff-no-rj',
#                         'canRate': True,
#                         'channelId': 'UCP4bf6IHJJQehibu6ai__cg',
#                         'likeCount': 0,
#                         'parentId': 'UgzDE2tasfmrYLyNkGt4AaABAg',
#                         'publishedAt': '2021-08-25T10:24:54Z',
#                         'textDisplay': 'Test',
#                         'textOriginal': 'Test',
#                         'updatedAt': '2021-08-25T10:24:54Z',
#                         'viewerRating': 'none'}},
#            {'etag': 'aq3GnPE4sTr6pxAKwsOILPdzIT4',
#             'id': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjXg9Wp6348hPTN',
#             'kind': 'youtube#comment',
#             'snippet': {'authorChannelId': {'value': 'UCDFCBYdvS_3DlxOx2dzvCNg'},
#                         'authorChannelUrl': 'http://www.youtube.com/@testnikanal9990',
#                         'authorDisplayName': '@testnikanal9990',
#                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lrn07lLxsGSa8oA_vU0ocR2-EBGH8HRz7iGOp4fATRob2g7iIOyX2ocmnImtbs=s48-c-k-c0x00ffffff-no-rj',
#                         'canRate': True,
#                         'channelId': 'UCP4bf6IHJJQehibu6ai__cg',
#                         'likeCount': 0,
#                         'parentId': 'UgzDE2tasfmrYLyNkGt4AaABAg',
#                         'publishedAt': '2022-01-05T15:15:55Z',
#                         'textDisplay': 'This is the original comment.',
#                         'textOriginal': 'This is the original comment.',
#                         'updatedAt': '2022-01-05T15:15:55Z',
#                         'viewerRating': 'none'}},
#            {'etag': 'ycS1zLlZj4ELQ-xeRqCj-gv6B2s',
#             'id': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjXg9b9u_jepBLx',
#             'kind': 'youtube#comment',
#             'snippet': {'authorChannelId': {'value': 'UC01i3Q1PqxgCRjDM-jtwIrA'},
#                         'authorChannelUrl': 'http://www.youtube.com/@jikochi',
#                         'authorDisplayName': '@jikochi',
#                         'authorProfileImageUrl': 'https://yt3.ggpht.com/e07lAkQ1h2b-79tGOnNB9qYda4IK_DZ3_GLwrEt2WrBGEaBrLpGCImkCoLiV_2TL-awKt4wyOw=s48-c-k-c0x00ffffff-no-rj',
#                         'canRate': True,
#                         'channelId': 'UCP4bf6IHJJQehibu6ai__cg',
#                         'likeCount': 0,
#                         'parentId': 'UgzDE2tasfmrYLyNkGt4AaABAg',
#                         'publishedAt': '2022
s48-c-k-c0x00ffffff-no-rj',
#                         'canRate': True,
#                         'channelId': 'UCP4bf6IHJJQehibu6ai__cg',
#                         'likeCount': 0,
#                         'parentId': 'UgzDE2tasfmrYLyNkGt4AaABAg',
#                         'publishedAt': '2022-12-18T08:51:15Z',
#                         'textDisplay': 'I am tring to test how can i send a '
#                                        'comment on my videos from my '
#                                        'applications',
#                         'textOriginal': 'I am tring to test how can i send a '
#                                         'comment on my videos from my '
#                                         'applications',
#                         'updatedAt': '2022-12-18T08:51:15Z',
#                         'viewerRating': 'none'}},
#            {'etag': 'yEbSeR8S9rnEIa2SbZbpIMmCEY0',
#             'id': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjXg9oxGU3v2p7A',
#             'kind': 'youtube#comment',
#             'snippet': {'authorChannelId': {'value': 'UCg_UfTLHyFCRDhYJleiZtPg'},
#                         'authorChannelUrl': 'http://www.youtube.com/@haoboliu2810',
#                         'authorDisplayName': '@haoboliu2810',
#                         'authorProfileImageUrl': 'https://yt3.ggpht.com/hKpx6gNIn29r_aJ-epRe6FSFmRkzdbF1sHuHU0aipwA_XDfxyJ6KZmgKIozRXQn5HrzzydS20w=s48-c-k-c0x00ffffff-no-rj',
#                         'canRate': True,
#                         'channelId': 'UCP4bf6IHJJQehibu6ai__cg',
#                         'likeCount': 0,
#                         'parentId': 'UgzDE2tasfmrYLyNkGt4AaABAg',
#                         'publishedAt': '2023-04-26T01:17:24Z',
#                         'textDisplay': 'This is the original comment.',
#                         'textOriginal': 'This is the original comment.',
#                         'updatedAt': '2023-04-26T01:17:24Z',
#                         'viewerRating': 'none'}}],
#  'kind': 'youtube#commentListResponse',
#  'pageInfo': {'resultsPerPage': 20}}

# %%
comments_Statistics_list=[]

for i in range(10):
            comments_Statistics = {'comment_ID' : comments['items'][0]['id'],
                                   'commentor_Name' : comments['items'][0]['snippet']['authorDisplayName'],
                                   'comments_Text' : comments['items'][0]['snippet']['textOriginal'],
                                   'updated_At' : comments['items'][0]['snippet']['updatedAt']}
comments_Statistics_list.append(comments_Statistics)
pprint(comments_Statistics_list)
# Out:
# [{'comment_ID': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjXg8ilIKfmOr81',
#   'commentor_Name': '@burakkarakus5868',
#   'comments_Text': 'https://www.youtube.com/watch?v=7_2CJs_VZk4',
#   'updated_At': '2018-07-16T13:05:07Z'}]

# %%
request = youtube.channelSections().list(
        part="snippet,contentDetails",
        channelId="UC_x5XG1OV2P6uZZ5FSM9Ttw"
    )
sections = request.execute()
pprint(sections)

# %%
channel_sections_list = []  # List to store section details for each iteration

# Loop 10 times
for i in range(10):
    # Assuming `sections` is your response containing items
    section_details = {
        'playlist_ID': sections['items'][i]['id'],
        'playlist_position': sections['items'][i]['snippet']['position'],
        'playlist_Type': sections['items'][i]['snippet']['type']
    }
    channel_sections_list.append(section_details)

# Print or return the list of section details
pprint(channel_sections_list)

# %%
 comments_Statistics = {'comment_ID' : comments['items'][0]['id'],
                                   'commentor_Name' : comments['items'][0]['snippet']['authorDisplayName'],
                                   'comments_Text' : comments['items'][0]['snippet']['textOriginal'],
                                   'updated_At' : comments['items'][0]['snippet']['updatedAt']}
